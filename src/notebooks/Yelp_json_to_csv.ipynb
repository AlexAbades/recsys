# %%
import pandas as pd
import json
import sys 


file_path = "../data/raw/YELP/yelp_academic_dataset_business.json"

data = []

with open(file_path, "r") as file:
    for i, line in enumerate(file):
        if i % 1000 == 0:
            print(i)
        if i < 999999999999:  
            json_obj = json.loads(line)

            data.append(json_obj)
        else:
            break  # Stop reading after the 10th line
df = pd.DataFrame(data)
# df.to_csv('../data/raw/YELP/yelp_academic_dataset_business.csv')
# Out:
# 0
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# 11000
# 12000
# 13000
# 14000
# 15000
# 16000
# 17000
# 18000
# 19000
# 20000
# 21000
# 22000
# 23000
# 24000
# 25000
# 26000
# 27000
# 28000
# 29000
# 30000
# 31000
# 32000
# 33000
# 34000
# 35000
# 36000
# 37000
# 38000
# 39000
# 40000
# 41000
# 42000
# 43000
# 44000
# 45000
# 46000
# 47000
# 48000
# 49000
# 50000
# 51000
# 52000
# 53000
# 54000
# 55000
# 56000
# 57000
# 58000
# 59000
# 60000
# 61000
# 62000
# 63000
# 64000
# 65000
# 66000
# 67000
# 68000
# 69000
# 70000
# 71000
# 72000
# 73000
# 74000
# 75000
# 76000
# 77000
# 78000
# 79000
# 80000
# 81000
# 82000
# 83000
# 84000
# 85000
# 86000
# 87000
# 88000
# 89000
# 90000
# 91000
# 92000
# 93000
# 94000
# 95000
# 96000
# 97000
# 98000
# 99000
# 100000
# 101000
# 102000
# 103000
# 104000
# 105000
# 106000
# 107000
# 108000
# 109000
# 110000
# 111000
# 112000
# 113000
# 114000
# 115000
# 116000
# 117000
# 118000
# 119000
# 120000
# 121000
# 122000
# 123000
# 124000
# 125000
# 126000
# 127000
# 128000
# 129000
# 130000
# 131000
# 132000
# 133000
# 134000
# 135000
# 136000
# 137000
# 138000
# 139000
# 140000
# 141000
# 142000
# 143000
# 144000
# 145000
# 146000
# 147000
# 148000
# 149000
# 150000

# %%
business_categories = set()
for row in df.categories:
  if row == None:
    continue
  for element in row.split(','):
    business_categories.add(element.strip().lower())

len(business_categories)

# %%
from collections import defaultdict



business_attributes = defaultdict(int)
for row in df.attributes:
  if row != None:
    for element in list(row.keys()):
      business_attributes[element] += 1

# %%
sorted_attributes = sorted(business_attributes.items(), key=lambda x: x[1], reverse=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 sorted_attributes = sorted(business_attributes.items(), key=lambda x: x[1], reverse=True)
#
# NameError: name 'business_attributes' is not defined
